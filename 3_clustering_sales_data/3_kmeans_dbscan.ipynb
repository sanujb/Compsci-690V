# %%
from bokeh.io import output_notebook, show
from bokeh.layouts import column, row, widgetbox
from bokeh.plotting import figure
from bokeh.models import HoverTool, ColumnDataSource, LabelSet, CustomJS, Slider, Range1d
from bokeh.models.widgets import Select, Panel, Tabs
import pandas as pd
import os
import numpy as np
from scipy import stats
from scipy.optimize import curve_fit
import math
import copy
import csv
from sklearn.cluster import KMeans, DBSCAN
from sklearn import preprocessing

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6b86c748-bc10-420c-8ea0-b720690fcd26">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Clustering Data Set 1
# <br>
# The data has been standarized by <b>transforming it to a range of 0 to 100.</b> <br>
# The two clustering algorithms selected are: <br>
# 1. K-Means: K-means clustering aims to partition 'n' observations into 'k' clusters <b>(K here is 2, after some visual experimentation)</b> in which each observation belongs to the cluster with the nearest mean, serving as a prototype of the cluster.<br>
# 2. DBScan: It is a density-based clustering algorithm: given a set of points in some space, it groups together points that are closely packed together (points with many nearby neighbors), marking as outliers points that lie alone in low-density regions (whose nearest neighbors are too far away). <br>
# For DBScan: e: The maximum distance between two samples for them to be considered as in the same neighborhood. <b> This has been set to 10</b><br>
# min_samples: The number of samples (or total weight) in a neighborhood for a point to be considered as a core point. This includes the point itself. <b>This has also been set to10</b>

# %%
with open('Wholesale customers data.csv', 'rt') as csvfile:
    original_data = csv.reader(csvfile, delimiter=',')
    original_data = np.array(list(original_data))

#separating column names from data
columns = original_data[0]
original_data = original_data[1:,:]
original_data = original_data.astype(np.float)
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0, 100))
original_data_minmax = min_max_scaler.fit_transform(original_data)
kmeans = KMeans(n_clusters=2, max_iter=750).fit(original_data_minmax[:,2:])
DBScan = DBSCAN(eps=10, min_samples=10, metric='euclidean', algorithm='auto', leaf_size=30, p=None, n_jobs=-1).fit(original_data_minmax[:,3:])
labels_DBScan = DBScan.labels_ + 1
labels_KMeans = kmeans.labels_

colorscheme = {
    0: 'green',
    1: 'red',
    2: 'yellow',
    3: 'navy'
}
    
legendScheme = {
    0: 'Cluster 1',
    1: 'Cluster 2',
    2: 'Cluster 3',
    3: 'Cluster 4'
}
    
plots_KMeans = []
plots_DBScan = []
plotNum = 0
actualPlotNum = 1
ToPlot = [1,3,5,6,8,10,11,12,13,14,15,18,24]
for i in range(2,len(original_data_minmax[0])):
    for j in range(2,len(original_data_minmax[0])):
        if j == i:
            continue
        if plotNum not in ToPlot:
            plotNum+=1
            continue
        #KMeans
        plots_KMeans.append(figure(plot_width = 400, plot_height = 400, title='KMeans Plot '+str(actualPlotNum)+' - X: Column '+str(i+1)+', Y: Column'+str(j+1)))
        for k in range(max(labels_KMeans)+1):
            plots_KMeans[-1].scatter(x=[original_data_minmax[ind,i] for ind,val in enumerate(labels_KMeans) if val == k], y=[original_data_minmax[ind,j] for ind,val in enumerate(labels_KMeans) if val == k], marker='x', size=5, line_color = colorscheme[k], legend=legendScheme[k])
            plots_KMeans[-1].circle(x=kmeans.cluster_centers_[k][i-2],y=kmeans.cluster_centers_[k][j-2], size=10)
        plots_KMeans[-1].legend.click_policy="hide"
        plots_KMeans[-1].xaxis.axis_label = columns[i]
        plots_KMeans[-1].yaxis.axis_label = columns[j]
        #DBScan
        plots_DBScan.append(figure(plot_width = 400, plot_height = 400, title='DBScan Plot '+str(actualPlotNum)+' - X: Column '+str(i+1)+', Y: Column '+str(j+1), x_range=plots_KMeans[-1].x_range, y_range=plots_KMeans[-1].y_range))
        for k in range(max(labels_DBScan)+1):
            plots_DBScan[-1].scatter(x=[original_data_minmax[ind,i] for ind,val in enumerate(labels_DBScan) if val == k], y=[original_data_minmax[ind,j] for ind,val in enumerate(labels_DBScan) if val == k], marker='x', size=5, line_color = colorscheme[k], legend=legendScheme[k])
        plots_DBScan[-1].legend.click_policy="hide"
        plots_DBScan[-1].xaxis.axis_label = columns[i]
        plots_DBScan[-1].yaxis.axis_label = columns[j]
        
        show(row(plots_KMeans[-1],plots_DBScan[-1]))
        plotNum+=1
        actualPlotNum+=1
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8d64ca85-55bd-4a53-90e5-f9d1110e4c6a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8d64ca85-55bd-4a53-90e5-f9d1110e4c6a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8d64ca85-55bd-4a53-90e5-f9d1110e4c6a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8d64ca85-55bd-4a53-90e5-f9d1110e4c6a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"690f95bc-2a1d-43e1-981f-4258728f0029":{"roots":{"references":[{"attributes":{},"id":"5d9847a5-e789-4a4b-afbb-d0ca4a542831","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"value":10.807841981982914},"y":{"value":5.959193349913624}},"id":"4363d08a-fb9a-494b-b056-de3a2ee33703","type":"Circle"},{"attributes":{"data_source":{"id":"c05e802f-3a77-4dc4-a2a7-e1a7a2bdccc5","type":"ColumnDataSource"},"glyph":{"id":"da93295a-45a1-4574-8ccb-50094c9b636a","type":"X"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"94912415-3a2e-461f-b7e0-d0d7453f5d2b","type":"X"},"selection_glyph":null},"id":"826231ba-f512-44fe-8f42-662c0111a2e9","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"DBScan Plot 1 - X: Column 3, Y: Column 5"},"id":"9f4a571f-998c-4e7b-8c71-3941f34e7878","type":"Title"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"value":10.807841981982914},"y":{"value":5.959193349913624}},"id":"b8d30541-886f-4349-bd42-45e3ed5229d8","type":"Circle"},{"attributes":{"children":[{"id":"5739b9e2-258e-4993-be44-b8c649ed14a0","subtype":"Figure","type":"Plot"},{"id":"7298cc19-212c-4d5a-abbb-b811fa6caee7","subtype":"Figure","type":"Plot"}]},"id":"69b8b237-c90e-4386-859a-a8265542ad57","type":"Row"},{"attributes":{},"id":"9e3db37b-96fd-44f8-8cb9-9de7b7f48696","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Fresh","formatter":{"id":"9e3db37b-96fd-44f8-8cb9-9de7b7f48696","type":"BasicTickFormatter"},"plot":{"id":"7298cc19-212c-4d5a-abbb-b811fa6caee7","subtype":"Figure","type":"Plot"},"ticker":{"id":"bfa59809-3684-42d4-8116-770df18a692c","type":"BasicTicker"}},"id":"ce71ede9-641f-45ac-9e7c-cf2bcaafad56","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"61ac7959-42af-4f8d-8920-9dbdfc2a9a79","type":"PanTool"},{"id":"f333316d-83cb-484e-81ca-0023696d0ecf","type":"WheelZoomTool"},{"id":"2bf65fcc-9322-41f9-9747-2419b60269d8","type":"BoxZoomTool"},{"id":"ce0837d2-ce5a-4585-a9df-4ae0084eb5c3","type":"SaveTool"},{"id":"7318162b-b890-4490-bba9-8e1cd5350a98","type":"ResetTool"},{"id":"579930fa-18c1-4032-a1b3-4cb0a9d04120","type":"HelpTool"}]},"id":"9719be6f-599b-4469-bcee-4bc56e3587f6","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"7298cc19-212c-4d5a-abbb-b811fa6caee7","subtype":"Figure","type":"Plot"},"ticker":{"id":"08e34e34-544e-4fe3-92fa-8d76d08b1a24","type":"BasicTicker"}},"id":"868db021-38a2-47ae-b6da-0b948eb08bc0","type":"Grid"},{"attributes":{"label":{"value":"Cluster 2"},"renderers":[{"id":"3ad586cb-9b34-4e22-95ae-32aaa4e42476","type":"GlyphRenderer"}]},"id":"7817d6ea-b33a-4e25-a385-fbc50199c6b2","type":"LegendItem"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"a3bf94fc-45af-4070-8f53-fe8a23b19f50","type":"X"},{"attributes":{"axis_label":"Grocery","formatter":{"id":"65679084-26a1-4a12-9f99-28d72cf6f639","type":"BasicTickFormatter"},"plot":{"id":"7298cc19-212c-4d5a-abbb-b811fa6caee7","subtype":"Figure","type":"Plot"},"ticker":{"id":"08e34e34-544e-4fe3-92fa-8d76d08b1a24","type":"BasicTicker"}},"id":"960350ac-b2bb-4c04-883f-cbf7b4c5a2cf","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"green"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"da93295a-45a1-4574-8ccb-50094c9b636a","type":"X"},{"attributes":{"overlay":{"id":"19d5018c-1d81-4a68-85b1-e0535aec8745","type":"BoxAnnotation"},"plot":{"id":"7298cc19-212c-4d5a-abbb-b811fa6caee7","subtype":"Figure","type":"Plot"}},"id":"2bf65fcc-9322-41f9-9747-2419b60269d8","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_al ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="95f21359-4327-4783-a712-4776e01a98da"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("95f21359-4327-4783-a712-4776e01a98da");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("95f21359-4327-4783-a712-4776e01a98da");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '95f21359-4327-4783-a712-4776e01a98da' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5faa3547-9261-4523-95b6-bfe6b61a2798":{"roots":{"references":[{"attributes":{"label":{"value":"Cluster 2"},"renderers":[{"id":"c55f5439-d480-4bd0-aa27-870af5431673","type":"GlyphRenderer"}]},"id":"4b5ae507-ab71-4ec2-a476-a028df5b6cd8","type":"LegendItem"},{"attributes":{"data_source":{"id":"291776b2-c667-4489-899a-a711ad928a5a","type":"ColumnDataSource"},"glyph":{"id":"48259764-19aa-4ce3-a422-f931556065ab","type":"X"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"846eb19d-a83b-42d9-bb8e-f26c40bf901e","type":"X"},"selection_glyph":null},"id":"2b61454d-dc89-47c0-ab7d-dffe8b539bae","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"green"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"48259764-19aa-4ce3-a422-f931556065ab","type":"X"},{"attributes":{"callback":null,"data":{}},"id":"81e1be2d-d38a-438a-bc88-155a5a3a5f3c","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"value":10.807841981982914},"y":{"value":4.099513133770036}},"id":"506cacf4-809f-471c-93ee-08d6cd539946","type":"Circle"},{"attributes":{"data_source":{"id":"81e1be2d-d38a-438a-bc88-155a5a3a5f3c","type":"ColumnDataSource"},"glyph":{"id":"cf09ccf1-a676-4b0e-9c51-4b7c1f63a1ce","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"506cacf4-809f-471c-93ee-08d6cd539946","type":"Circle"},"selection_glyph":null},"id":"21a22fd7-7bf2-409f-826a-32e013edb151","type":"GlyphRenderer"},{"attributes":{},"id":"ec777377-b657-424b-8051-19f3b939aa6e","type":"ToolEvents"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"value":10.807841981982914},"y":{"value":4.099513133770036}},"id":"cf09ccf1-a676-4b0e-9c51-4b7c1f63a1ce","type":"Circle"},{"attributes":{"plot":null,"text":"DBScan Plot 2 - X: Column 3, Y: Column 7"},"id":"99783978-986d-4281-9662-2b35129991ab","type":"Title"},{"attributes":{"below":[{"id":"ccb74006-63ba-4afa-85dd-3aebc1300b2a","type":"LinearAxis"}],"left":[{"id":"f783b701-2501-41f5-a92d-7ef4fc75a915","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"ccb74006-63ba-4afa-85dd-3aebc1300b2a","type":"LinearAxis"},{"id":"0af90a2d-3f89-404c-9f03-bba878b04fbb","type":"Grid"},{"id":"f783b701-2501-41f5-a92d-7ef4fc75a915","type":"LinearAxis"},{"id":"18b2dd39-fb49-43a3-8532-bf3177f201c5","type":"Grid"},{"id":"7d452504-7b04-4f1f-8dee-f1dbc9230930","type":"BoxAnnotation"},{"id":"040c8779-8d89-4d86-8b7c-367dd144cf9c","type":"Legend"},{"id":"2b61454d-dc89-47c0-ab7d-dffe8b539bae","type":"GlyphRenderer"},{"id":"32a2019b-3611-48c3-a99e-7e5cd968c3b8","type":"GlyphRenderer"}],"title":{"id":"99783978-986d-4281-9662-2b35129991ab","type":"Title"},"tool_events":{"id":"ec777377-b657-424b-8051-19f3b939aa6e","type":"ToolEvents"},"toolbar":{"id":"7bbcff04-2dc5-41a5-806e-739aa41a4fbc","type":"Toolbar"},"x_range":{"id":"1caa2e1f-51ab-4cf4-8962-5547eb5a546f","type":"DataRange1d"},"y_range":{"id":"79c2e1a6-47fb-4d97-9d1a-a7e330a7a4ff","type":"DataRange1d"}},"id":"43dbac3b-1057-49cd-a65e-bde25cfe09ec","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"Fresh","formatter":{"id":"783e8a41-c1b1-416f-975c-35988600d3fd","type":"BasicTickFormatter"},"plot":{"id":"43dbac3b-1057-49cd-a65e-bde25cfe09ec","subtype":"Figure","type":"Plot"},"ticker":{"id":"d02f4d12-96ce-40c2-95e7-b95871d497d4","type":"BasicTicker"}},"id":"ccb74006-63ba-4afa-85dd-3aebc1300b2a","type":"LinearAxis"},{"attributes":{},"id":"d02f4d12-96ce-40c2-95e7-b95871d497d4","type":"BasicTicker"},{"attributes":{"axis_label":"Detergents_Paper","formatter":{"id":"bf738259-5d39-4a3f-b276-4edd717c804c","type":"BasicTickFormatter"},"plot":{"id":"43dbac3b-1057-49cd-a65e-bde25cfe09ec","subtype":"Figure","type":"Plot"},"ticker":{"id":"05791f8c-f04 ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2ece07cc-1cd8-454f-a5eb-529ab202f840"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2ece07cc-1cd8-454f-a5eb-529ab202f840");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2ece07cc-1cd8-454f-a5eb-529ab202f840");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2ece07cc-1cd8-454f-a5eb-529ab202f840' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"532b4c29-84a0-4a72-bbf8-480114812376":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"93910f84-fefa-4d1f-ac6c-ac42efadfda1","type":"PanTool"},{"id":"51e3727a-85e9-41dd-bacd-a056a2192ca0","type":"WheelZoomTool"},{"id":"0357a903-a940-4f9e-93df-59333b6a2688","type":"BoxZoomTool"},{"id":"8a181b4d-9dd9-4aec-b222-0878954b15b4","type":"SaveTool"},{"id":"a5c26411-0824-4375-9d38-8b85758b2ce5","type":"ResetTool"},{"id":"bdc2e259-63e0-4406-85c4-4016790b1f75","type":"HelpTool"}]},"id":"df6687e7-37e9-40bb-9db9-ea2ddf62d99e","type":"Toolbar"},{"attributes":{},"id":"00495a6a-b01e-418f-9b7a-6cf191547bb7","type":"BasicTicker"},{"attributes":{},"id":"a09bca8e-e878-4f62-8080-b3148bd7f7ec","type":"ToolEvents"},{"attributes":{"click_policy":"hide","items":[{"id":"8a0e57b9-2d46-445b-93d3-00cb239fe622","type":"LegendItem"},{"id":"dd238036-4fdf-4756-83ea-9a849702dd59","type":"LegendItem"}],"plot":{"id":"5a722da1-410b-44b4-bde4-cf65d0a0b9d1","subtype":"Figure","type":"Plot"}},"id":"875837b5-8699-41fa-8b7d-c11f78f48c56","type":"Legend"},{"attributes":{},"id":"3c47c803-f4ac-4670-8d35-269dc9f6ca71","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"76b2b594-c650-445f-ab6f-dab0d58ec282","type":"BoxAnnotation"},{"attributes":{},"id":"511952f1-5252-4897-be67-4bc10bfad1c4","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[15.029342483286358,49.51867434609153,27.81612951540651,21.341720790272728,15.032065683591357,29.940225753305285,19.081464537124027,73.80417466606757,29.07969445692578,40.626063750119144,52.16834824285501,28.462889587843634,17.213349127895103,62.82695423661888,100.0,37.33099138107104,14.420707215119208,22.703320942771946,11.34076767016598,14.480617621829174,21.337635989815233,17.153438721185136,35.1388151355473,10.378116362349033,40.265239709706854,59.76743869395314,17.95269801070218,19.530792587448772,15.870811377530874,17.256920332775078,38.49379791130537,22.52631292294705,31.423008319376933,18.056179622292117,10.082649129256703,17.44482115381997,28.048963141483874,5.013411761502118,34.06178941492042,20.187083860953393,6.705880751058645,9.40729545361709,19.860299824353582,13.60102392331468,8.45417534686764,17.413504350312486,21.013575153520417],"y":[5.352748154224774,23.513571352141813,3.66480008560117,4.091022577308556,0.5590826407960909,4.617113100545708,2.764204444127403,39.64671683846346,4.426293826015622,3.651424902807005,32.04604629596604,0.07311766594143454,10.880265363626638,14.368513036344831,20.439062667189784,8.198987052823057,7.8414238327923815,1.251025430680886,19.649035203481112,1.7708742019474266,4.929200699076221,13.92089025216678,0.17566073403003174,0.4556478938545494,100.00000000000001,32.853015657880654,2.7321040054214074,3.995612940043514,0.9844134536505332,4.946142597282162,10.803580982273425,2.2550558190961945,5.466883047401647,4.708064343546028,0.14088525876520314,5.764703784285052,0.8158861504440561,1.9028426721831864,8.699218889324822,10.004636730035312,7.6345543389092985,1.5033705460641296,5.330456182901166,1.0762563755037986,0.1016513892356529,6.561864678817277,12.954310375575133]}},"id":"6c4bc410-ff97-49aa-a765-d93157d1e062","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"377fbfa4-7a3b-4639-9169-991be338e08f","subtype":"Figure","type":"Plot"}},"id":"a2aa9a1c-a9b6-4702-8398-dea03fbd9e0d","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"5a722da1-410b-44b4-bde4-cf65d0a0b9d1","subtype":"Figure","type":"Plot"},"ticker":{"id":"00495a6a-b01e-418f-9b7a-6cf191547bb7","type":"BasicTicker"}},"id":"5dc8ed54-33ca-4f51-895e-ab87d5d7838e","type":"Grid"},{"attributes":{"d ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9ddf98ef-8004-45e5-9d95-253e4b133173"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9ddf98ef-8004-45e5-9d95-253e4b133173");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9ddf98ef-8004-45e5-9d95-253e4b133173");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9ddf98ef-8004-45e5-9d95-253e4b133173' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c7667bc4-eb7c-42bf-bac1-56de443639d2":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"1b0cbc23-e609-40f2-a990-78e9a5e11344","type":"X"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[15.029342483286358,49.51867434609153,27.81612951540651,21.341720790272728,15.032065683591357,29.940225753305285,19.081464537124027,73.80417466606757,29.07969445692578,40.626063750119144,52.16834824285501,28.462889587843634,17.213349127895103,62.82695423661888,100.0,37.33099138107104,14.420707215119208,22.703320942771946,11.34076767016598,14.480617621829174,21.337635989815233,17.153438721185136,35.1388151355473,10.378116362349033,40.265239709706854,59.76743869395314,17.95269801070218,19.530792587448772,15.870811377530874,17.256920332775078,38.49379791130537,22.52631292294705,31.423008319376933,18.056179622292117,10.082649129256703,17.44482115381997,28.048963141483874,5.013411761502118,34.06178941492042,20.187083860953393,6.705880751058645,9.40729545361709,19.860299824353582,13.60102392331468,8.45417534686764,17.413504350312486,21.013575153520417],"y":[20.347715489830453,23.730019293574912,27.974605775138233,18.006618019552256,25.86309106782931,23.20402686010541,23.661036679349404,59.89415480129773,31.169363096457094,28.954374467809906,64.2346702307684,49.392629638811336,30.758700971145863,99.99999999999999,34.6109488343016,34.52472056651972,16.04169136747254,31.239423564029874,37.497440098300224,20.971792577901848,28.958685881199003,21.40077821011673,21.35550836953124,21.34365198271123,19.557648986278924,21.737068454466083,24.92428080235403,26.628366944393544,25.429794022225334,18.069133513694126,42.78107720663526,39.32332366858165,36.197548961488295,21.98389687099173,26.698427411966325,23.24606314064908,14.620002802418702,20.66137081388706,19.01548875260032,28.92527242743352,72.53414100477488,28.361555126809442,22.115394979359106,24.026428964075144,22.850490962199682,20.134300527070284,32.59428522155275]}},"id":"e2cba0b3-43b5-4064-8705-7ae8f9e5c2ff","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"781617b7-35e9-441f-9179-c4a60a20596b","type":"LinearAxis"}],"left":[{"id":"cb7fb757-6609-49de-8ca1-1a2273f75e5a","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"781617b7-35e9-441f-9179-c4a60a20596b","type":"LinearAxis"},{"id":"2bd8418e-bd34-4d3f-81ac-90a0ba36ec49","type":"Grid"},{"id":"cb7fb757-6609-49de-8ca1-1a2273f75e5a","type":"LinearAxis"},{"id":"5e936e7c-6509-45d0-a2b4-99d08c175a6d","type":"Grid"},{"id":"b7090162-3a4d-40e8-a48e-97717df3192f","type":"BoxAnnotation"},{"id":"1e16064e-ad74-40a8-b161-f555661a122e","type":"Legend"},{"id":"70af055e-8c7b-4de8-83fd-9051461f2b40","type":"GlyphRenderer"},{"id":"af9b795d-3202-4ea8-91ec-ce5241fc6105","type":"GlyphRenderer"},{"id":"3447418d-c2f4-4ac6-b153-b4cc12c7668d","type":"GlyphRenderer"},{"id":"a43732bb-d96a-41ff-bcdc-d19c40b928bd","type":"GlyphRenderer"}],"title":{"id":"7a85656d-5c07-4288-8b61-51138bd06fc0","type":"Title"},"tool_events":{"id":"dd2ee92e-5d68-4b58-bc9b-c2eb3c4c3cc0","type":"ToolEvents"},"toolbar":{"id":"8d6f7f45-49d8-4421-97be-7cb26df8b57c","type":"Toolbar"},"x_range":{"id":"92df23f3-234d-4714-b6ae-3c4218e6390e","type":"DataRange1d"},"y_range":{"id":"5ccc0992-b40d-4e41-80bb-6d9202584cc3","type":"DataRange1d"}},"id":"216a7c98-c440-4388-9d22-2327e446d93c","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"dd2ee92e-5d68-4b58-bc9b-c2eb3c4c3cc0","type":"ToolEvents"},{"attributes":{"callback":null},"id":"92df23f3-234d-4714-b6ae-3c4218e6390e","type":"DataRange1d"},{"attributes":{"plot":{"id":"216a7c98-c440-4388-9d22-2327e446d93c","subtype":"Figure","type":"Plot"},"ticker":{"id":"cdee085d-f50b-4cf3-90af-d82c058c4108","type":"BasicTicker"}},"id":"2bd8418e-bd34-4d3f-81ac-90a0ba36ec49","type":"Grid"},{"attributes":{"active ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="12e3b9ca-b439-4b6d-a33d-6b96518d4e4a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("12e3b9ca-b439-4b6d-a33d-6b96518d4e4a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("12e3b9ca-b439-4b6d-a33d-6b96518d4e4a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '12e3b9ca-b439-4b6d-a33d-6b96518d4e4a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"10d3b697-bd03-45e6-a5bd-6ed7d212b109":{"roots":{"references":[{"attributes":{"plot":{"id":"aa29e680-bb64-4c24-b072-0d14dc150148","subtype":"Figure","type":"Plot"},"ticker":{"id":"de3ad650-1352-4aab-b51e-e8fbba33602f","type":"BasicTicker"}},"id":"f583eeda-988a-40f7-80f9-07b8097a91f1","type":"Grid"},{"attributes":{},"id":"de3ad650-1352-4aab-b51e-e8fbba33602f","type":"BasicTicker"},{"attributes":{},"id":"e0321bc5-8082-4c6c-91e7-fe089fcdf9c9","type":"BasicTicker"},{"attributes":{"axis_label":"Detergents_Paper","formatter":{"id":"69dccb5b-a39b-41ae-9271-9123d86f9b51","type":"BasicTickFormatter"},"plot":{"id":"aa29e680-bb64-4c24-b072-0d14dc150148","subtype":"Figure","type":"Plot"},"ticker":{"id":"e0321bc5-8082-4c6c-91e7-fe089fcdf9c9","type":"BasicTicker"}},"id":"0ff393c1-d06f-47f2-b9d6-6b0bc188e88c","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"aa29e680-bb64-4c24-b072-0d14dc150148","subtype":"Figure","type":"Plot"},"ticker":{"id":"e0321bc5-8082-4c6c-91e7-fe089fcdf9c9","type":"BasicTicker"}},"id":"120b1153-92a4-4e42-939c-c72ed09d3af5","type":"Grid"},{"attributes":{"axis_label":"Milk","formatter":{"id":"f6873df1-4154-45f3-a2d9-18df68e0bf37","type":"BasicTickFormatter"},"plot":{"id":"aa29e680-bb64-4c24-b072-0d14dc150148","subtype":"Figure","type":"Plot"},"ticker":{"id":"de3ad650-1352-4aab-b51e-e8fbba33602f","type":"BasicTicker"}},"id":"b03d04c5-3293-4d31-b0cd-008542d72b58","type":"LinearAxis"},{"attributes":{"callback":null},"id":"6dcd214a-21ad-42fe-9886-b27ceddd135a","type":"DataRange1d"},{"attributes":{"below":[{"id":"b03d04c5-3293-4d31-b0cd-008542d72b58","type":"LinearAxis"}],"left":[{"id":"0ff393c1-d06f-47f2-b9d6-6b0bc188e88c","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"b03d04c5-3293-4d31-b0cd-008542d72b58","type":"LinearAxis"},{"id":"f583eeda-988a-40f7-80f9-07b8097a91f1","type":"Grid"},{"id":"0ff393c1-d06f-47f2-b9d6-6b0bc188e88c","type":"LinearAxis"},{"id":"120b1153-92a4-4e42-939c-c72ed09d3af5","type":"Grid"},{"id":"3dae1b07-1b79-4468-a9b5-2ee90bc5a1c2","type":"BoxAnnotation"},{"id":"a4639c11-32de-4e9a-9bf2-bab46600ea61","type":"Legend"},{"id":"91e1223f-60ed-49ae-ae8c-e845c8e00514","type":"GlyphRenderer"},{"id":"b82369f1-dfe8-40a8-a4d2-582537a28d68","type":"GlyphRenderer"},{"id":"2632ebf8-8dce-4ced-8e5c-839266f6a21e","type":"GlyphRenderer"},{"id":"fce6bcf8-27bb-4563-b2ff-79a71fd6300f","type":"GlyphRenderer"}],"title":{"id":"b7ee2565-3a04-4ccc-a233-42ba75828cb0","type":"Title"},"tool_events":{"id":"7e8a6f2a-7897-429c-80d9-ba0c6b0b2593","type":"ToolEvents"},"toolbar":{"id":"0e9a3401-70b4-4732-adf6-f5cef810dcd3","type":"Toolbar"},"x_range":{"id":"a790312a-ac07-4059-a4a3-581a4d7b6120","type":"DataRange1d"},"y_range":{"id":"6dcd214a-21ad-42fe-9886-b27ceddd135a","type":"DataRange1d"}},"id":"aa29e680-bb64-4c24-b072-0d14dc150148","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"green"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"faee8e21-1a50-4034-a667-6bc7a1933ada","type":"X"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[15.029342483286358,49.51867434609153,27.81612951540651,21.341720790272728,15.032065683591357,29.940225753305285,19.081464537124027,73.80417466606757,29.07969445692578,40.626063750119144,52.16834824285501,28.462889587843634,17.213349127895103,62.82695423661888,100.0,37.33099138107104,14.420707215119208,22.703320942771946,11.34076767016598,14.480617621829174,21.337635989815233,17.153438721185136,35.1388151355473,10.378116362349033,40.265239709706854,59.76743869395314,17.95269801070218,19.530792587448772,15.870811377530874,17.256920332775078,38.49379791130537,22.52631292294705,31.423008319376933,18.056179622292117,10.082649129256703,17.44482115381997,28.048963141483874,5.013411761502118,34.06178941492042,20.187083860953393,6.705880751058645,9.40729545361709,19.860299824353582,13.60102392331468,8.45417534686764,17.413504350312486,21 ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c4eea3b3-1289-40bd-9954-4b75eadc3447"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c4eea3b3-1289-40bd-9954-4b75eadc3447");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c4eea3b3-1289-40bd-9954-4b75eadc3447");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c4eea3b3-1289-40bd-9954-4b75eadc3447' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"17cfd3ae-7003-4c43-8add-ef6e7af52aaf":{"roots":{"references":[{"attributes":{"data_source":{"id":"5c8c8e83-4a03-40e7-ac86-63532b479e5d","type":"ColumnDataSource"},"glyph":{"id":"c0ac96e8-558a-4cfe-b518-e0044bb61f35","type":"X"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a9e19d55-c6cf-4d90-8e30-dfe81bbaadb8","type":"X"},"selection_glyph":null},"id":"60ef30f4-3c1d-4d7f-860d-161a34055c57","type":"GlyphRenderer"},{"attributes":{"axis_label":"Grocery","formatter":{"id":"50b81c7e-8bc3-428e-8533-cbfb0d6706d0","type":"BasicTickFormatter"},"plot":{"id":"0a2a1746-1865-4d6e-adb6-1570ba19e6d4","subtype":"Figure","type":"Plot"},"ticker":{"id":"038f7ed2-858e-45e4-abf3-422aaff2251b","type":"BasicTicker"}},"id":"300b4bb5-ee83-455b-8505-be1cdf71609c","type":"LinearAxis"},{"attributes":{"click_policy":"hide","items":[{"id":"3dcfc2cc-10b5-4df9-9d7c-27519921c90a","type":"LegendItem"},{"id":"d85a0237-7edc-4c10-96b9-ead7a267706c","type":"LegendItem"}],"plot":{"id":"3ba0d454-7a3e-472d-b4cb-67e4d3a0e664","subtype":"Figure","type":"Plot"}},"id":"90bcb387-94b1-455e-8ddb-e91ec358a1e8","type":"Legend"},{"attributes":{},"id":"038f7ed2-858e-45e4-abf3-422aaff2251b","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"green"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"c0ac96e8-558a-4cfe-b518-e0044bb61f35","type":"X"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c70eb288-b929-4458-9b52-e1d61c025797","type":"PanTool"},{"id":"0d04a0ee-6247-4e2a-b137-025fb7e6044a","type":"WheelZoomTool"},{"id":"1701bd00-1a12-43ef-9586-4e4b2aad9689","type":"BoxZoomTool"},{"id":"d6e80cb3-cf5b-4ec8-a8f9-edde775e82c8","type":"SaveTool"},{"id":"03e7a9b7-588d-407c-86e6-ea10346225e5","type":"ResetTool"},{"id":"17612cf3-0036-4770-b7d3-7a5335c59d52","type":"HelpTool"}]},"id":"cbb208a1-024b-4b3e-ac2d-d2166a7b4d4b","type":"Toolbar"},{"attributes":{"below":[{"id":"300b4bb5-ee83-455b-8505-be1cdf71609c","type":"LinearAxis"}],"left":[{"id":"1114f5bc-d331-4030-998d-3c10643c3dd7","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"300b4bb5-ee83-455b-8505-be1cdf71609c","type":"LinearAxis"},{"id":"f6bfbc6c-4448-46da-8e6e-927266dee40a","type":"Grid"},{"id":"1114f5bc-d331-4030-998d-3c10643c3dd7","type":"LinearAxis"},{"id":"4f57f971-cb15-426b-8494-7d06f352d13c","type":"Grid"},{"id":"8952572f-7c3e-4747-a547-d729d27d178a","type":"BoxAnnotation"},{"id":"2c6a539b-08c7-4305-964b-703c08d03c44","type":"Legend"},{"id":"60ef30f4-3c1d-4d7f-860d-161a34055c57","type":"GlyphRenderer"},{"id":"d429860a-6525-4ce4-a9e4-7cca4e0cdbb9","type":"GlyphRenderer"},{"id":"db224f4b-d48f-49cf-9ebd-88525ddb49c4","type":"GlyphRenderer"},{"id":"da3eb6ad-c5ef-4664-8889-50298e39dccc","type":"GlyphRenderer"}],"title":{"id":"37a6d72a-554f-45cd-89f3-279071e41145","type":"Title"},"tool_events":{"id":"f78f2ff1-6a35-492b-b7f2-8515eebebb8b","type":"ToolEvents"},"toolbar":{"id":"cbb208a1-024b-4b3e-ac2d-d2166a7b4d4b","type":"Toolbar"},"x_range":{"id":"48ed9962-5498-4bb7-bd1c-e6bdce7ac99d","type":"DataRange1d"},"y_range":{"id":"c7e08cd9-4a8d-425a-96cb-7885bbffda85","type":"DataRange1d"}},"id":"0a2a1746-1865-4d6e-adb6-1570ba19e6d4","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":"KMeans Plot 6 - X: Column 5, Y: Column3"},"id":"37a6d72a-554f-45cd-89f3-279071e41145","type":"Title"},{"attributes":{},"id":"f78f2ff1-6a35-492b-b7f2-8515eebebb8b","type":"ToolEvents"},{"attributes":{"callback":null},"id":"c7e08cd9-4a8d-425a-96cb-7885bbffda85","type":"DataRange1d"},{"attributes":{"plot":{"id":"0a2a1746-1865-4d6e-adb6-1570ba19e6d4","subtype":"Figure","type":"Plot"}},"id":"17612cf3-0036-4770-b7d3-7a5335c59d52","type":"HelpTool"},{"attributes":{},"id":"2819b443-4577-408d-80bc-4da098aeb354","type":"BasicTicker"},{"attributes":{"click_policy":"hide","items":[{"id":"cf7b3fb5-8fb3-460b-b829-4a0deb52e6cb","type":"LegendItem"},{"id":"4b395a0 ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6255fc54-45f5-4669-87bb-92186c14e03c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6255fc54-45f5-4669-87bb-92186c14e03c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6255fc54-45f5-4669-87bb-92186c14e03c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6255fc54-45f5-4669-87bb-92186c14e03c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
# ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d9019ee2-eeb9-48ba-8cae-09cd89fd470a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d9019ee2-eeb9-48ba-8cae-09cd89fd470a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d9019ee2-eeb9-48ba-8cae-09cd89fd470a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd9019ee2-eeb9-48ba-8cae-09cd89fd470a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1b6f4e33-535e-4fe9-980b-328149401a8d":{"roots":{"references":[{"attributes":{"click_policy":"hide","items":[{"id":"909b183e-5e0b-4806-b2ad-ca9a4a4272a6","type":"LegendItem"},{"id":"3d2c71b7-d7e9-4e07-a9c2-d989a446c478","type":"LegendItem"}],"plot":{"id":"8ce2070f-7ca4-4a82-a980-775b6bedb56d","subtype":"Figure","type":"Plot"}},"id":"f28970a1-9733-4171-b53d-d017022c57b8","type":"Legend"},{"attributes":{"label":{"value":"Cluster 1"},"renderers":[{"id":"63a4432f-f3f1-4f47-9def-ccbcbc3a0eea","type":"GlyphRenderer"}]},"id":"909b183e-5e0b-4806-b2ad-ca9a4a4272a6","type":"LegendItem"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"21d50417-03f2-4654-b5eb-c6210acd09da","type":"X"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.310630464795214,2.854841890736967,3.911642890013806,10.484189073696667,6.3933995135099595,1.0535139044112811,0.747814081914404,2.701991979488528,0.6574189731115639,1.863782788771284,7.190520018407731,2.2927486687265795,0.4306094273880744,5.045690618631253,0.4421142594175268,0.6113996449937544,0.17914667017290117,1.3378476102820327,3.5829334034580236,1.058444546709618,1.7109328775228452,5.519032279271579,15.421405561764512,4.74985208073105,0.2892643481690882,5.137729274866873,0.7560318190782985,1.9311682335152192,1.8457037670107157,3.3906383538228915,0.3960949312997173,10.033857077115245,0.6574189731115639,1.3279863256853592,2.8006048254552627,3.1145223851160346,0.013148379462231283,16.397672736835183,15.58904739990796,3.3002432450200514,0.26789823154296233,1.2523831437775292,0.8480704753139174,2.7003484320557494,0.9187430149234106,6.30300440470712,0.3517191506146867,0.8332785484189073,1.181710604168036,3.962592860429952,1.696140950627835,0.02136611662612583,0.9384655841167575,0.17092893300900663,0.11669186772730258,6.786207349944119,4.718624679508251,6.0794819538491875,0.2465321149168365,2.0232068897508384,9.606534744592729,1.239234764315298,17.451186641246466,14.540464137795016,13.324239037538623,2.0708697653014267,7.2020248504371835,12.334823483005719,1.3871540332654,3.4037867332851226,1.385510485832621,0.6656367102754585,0.4240352376569588,1.170205772138584,3.7719413582275982,1.895010189994083,15.958845572283215,5.617645125238314,5.459864571691539,14.246269147327592,0.2974820853329827,0.6820721846032476,0.19722569193346917,1.2310170271514036,1.4298862665176515,9.2268752876208,5.303727565577542,2.577082374597331,4.168036289527316,29.588784432318715,2.154690684373151,1.4545394780093353,0.17750312274012225,4.020117020577214,0.364867530076918,3.6996252711853264,1.2819669975675496,14.509236736572216,5.251134047728617,4.1581750049306425,4.421142594175268,2.452172769706134,2.665833935967392,8.740385247518242,6.36217211228716,3.9313654592071527,3.895207415686017,3.231214252843337,3.564854381697456,7.826572874893169,27.13989875747814,13.427782525803694,1.405233055025968,0.19229504963513244,2.7825258036946945,10.339556899612122,0.52757872592203,0.9055946354611794,0.6754979948721319,1.1422654657813422,1.8818618105318519,7.47814081914404,1.0452961672473866,0.21366116626125828,1.3148379462231279,3.704555913483663,0.4864900401025573,4.881335875353362,13.805798435342844,0.1528499112484386,1.4808362369337977,2.0725133127342055,6.6185655118006705,1.273749260403655,1.3608572743409373,0.8316350009861284,4.891197159950036,1.239234764315298,0.0821773716389455,0.34185786601801327,0.47991585037144174,5.510814542107685,1.4874104266649135,0.6130431924265334,1.313194398790349,1.753665110775097,4.338965222536323,3.849188087568207,4.133521793438959,7.231608704227204,1.5909539149299847,0.6245480244559858,2.248372888041549,3.901781605417132,1.7931102491617907,0.5062126092959042,1.4989152586943657,4.0924331076194855,0.04437578068503057,12.068568798895535,2.838406416409178,1.8522779567418315,7.317073170731707,0.619617382157649,0.6870028269015843,0.08053382420616659,3.543488265071329 ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="98b50222-ef3a-4de0-87db-abc6d39f5c16"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("98b50222-ef3a-4de0-87db-abc6d39f5c16");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("98b50222-ef3a-4de0-87db-abc6d39f5c16");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '98b50222-ef3a-4de0-87db-abc6d39f5c16' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"922dbd1e-5d6a-439a-8a57-fa7c7147ec15":{"roots":{"references":[{"attributes":{"data_source":{"id":"08cffcc0-f92b-4b36-9f44-51279e229dd8","type":"ColumnDataSource"},"glyph":{"id":"23763f67-0c1d-444d-a284-5eeb08352ae4","type":"X"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f36e6aaf-54b5-4a98-88b7-a4a0e706e5d9","type":"X"},"selection_glyph":null},"id":"51e6ea45-da75-479e-a19d-76160f167f85","type":"GlyphRenderer"},{"attributes":{"label":{"value":"Cluster 2"},"renderers":[{"id":"055c815f-4c7f-49ca-9b5d-eefff7f331c5","type":"GlyphRenderer"}]},"id":"7d1cc908-40d0-43e2-981a-407ec9243040","type":"LegendItem"},{"attributes":{},"id":"2d7e696a-e5c8-4a11-aeff-390eb8ac77f4","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"5d81211a-27f7-4056-ba2e-4d92ffdb152c","subtype":"Figure","type":"Plot"},{"id":"048efde3-917e-4b84-a523-8005ed105ff5","subtype":"Figure","type":"Plot"}]},"id":"b8e43b4d-be77-4c4b-bcae-aafe81864b09","type":"Row"},{"attributes":{"data_source":{"id":"fd31906b-c713-49c3-8af7-bc42b49cf57f","type":"ColumnDataSource"},"glyph":{"id":"0d66d6af-04c3-4ad5-bf74-dad27de28fc3","type":"X"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4fcdf008-318a-432b-81fe-a705c6fa4c38","type":"X"},"selection_glyph":null},"id":"d9895850-68eb-4fe9-8d00-a51f6f743f58","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"DBScan Plot 13 - X: Column 7, Y: Column 8"},"id":"8ca82838-85f7-44d9-b50f-1b19690d08bc","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"f36e6aaf-54b5-4a98-88b7-a4a0e706e5d9","type":"X"},{"attributes":{"click_policy":"hide","items":[{"id":"bcffb143-47be-4bf9-9247-af35418bb5fb","type":"LegendItem"},{"id":"008f49ef-dd37-4872-af61-43a18148e173","type":"LegendItem"}],"plot":{"id":"5d81211a-27f7-4056-ba2e-4d92ffdb152c","subtype":"Figure","type":"Plot"}},"id":"31d796f1-2051-495f-b045-2bf664248104","type":"Legend"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[6.542719968645894,8.058984910836761,8.605232216343326,1.2345679012345678,4.345483049186752,4.38957475994513,7.684205369390554,8.127572016460904,4.196061140505584,14.633548892808152,1.337448559670782,9.499314128943759,16.421712718009015,12.382422104644327,2.3540074466000394,11.035175387027238,0.8989809915735841,6.770527140897511,6.160591808739956,5.526161081716637,0.9112286890064668,5.825004899078973,10.97148736037625,9.798157946306095,0.5854399372917891,0.2376053301979228,2.704291593180482,5.219968645894571,2.00127376053302,2.2413286302175193,0.8769351361943954,1.1757789535567313,10.376249265138153,2.104154418969234,15.929355281207132,0.5119537526944934,2.79737409367039,6.300215559474818,16.892024299431707,11.304624730550655,12.536743092298646,1.4844209288653734,3.7600431118949635,6.329610033313736,13.737017440721143,0.49235743680188127,4.950519302371154,18.540564373897706,0.5486968449931413,7.547031158142269,10.023515579071134,9.972075249853027,18.79776601998824,3.047227121301195,8.487654320987653,12.585733882030178,1.922888496962571,1.59954928473447,0.27679796198314716,10.214579659024103,3.228493043307858,1.8640995492847345,4.649225945522241,0.0,1.2884577699392514,0.729962766999804,2.936997844405252,1.4868704683519498,19.14315108759553,8.656672545561435,1.3398980991573584,9.39153439153439,3.860474230844601,0.3968253968253968,1.1047423084460122,0.16166960611405057,1.5285126396237507,0.1665686850872036,12.333431314912795,0.5388986870468352,9.482167352537722,0.12492651381540269,0.12982559278855577,0.519302371154223,19.674701156182635,16.566235547717028,11.194395453654712,3.617969821673525,3.6449147560258672,0.3331373701744072,16.723006074857928,6.128747795414461,0.4066235547717029,15.809327846364882,1.1757789535567313,1.4256319811875366,0.2816970409563002,0.668724279835391,0.7520086223789928,0.77405447 ...

# %% [markdown]
# ### Discussion
# The above were selected from all the possible combinations of plots as they were deemed meaningful to the discussion in some way.<br>
# On the left is the KMeans implementation and on the right is the same graph clustered by DBScan.<br>
# Each of the plots is linked to the one on its side in panning and zooming, so one can observe the same area of the data in both clustering techniques together. Also, the legends for the clusters can be clicked to hide/show the clusters. In the KMeans plots, th cluster centers are shown in blue circles. The clusters are otherwise color coded.<br>
# Some important comparisons and observations from these visualizations:
# 1. K-Means was run with K = (2,3,4,5) but for all K > 2, the clusters were being formed randomly and changed on re-runs. This means that the data inherently does not have too many clusters, or K Means just does not have the capability to cluster the data well. DBScan was run with various parameter values, but since the data is of varying density, a lot clusters were often very small (due to small min_samples or e) or it turned  out to be just one big cluster and some outliers (due to bigger min_samples or e). A value of 10,10 for min_samples and e turned up clusters similar to K Means.
# 2. DBScan return just 1 cluster, and the other points are all outliers which lie in no cluster. All these points are shown as Cluster 1 (green) in all the plots. DB Scan, is, therefore, not a good clustering algorithm for the data set.
# 3. Plots 1, 2, 3, 6, 8, 9 seem very similar with respect to clusters from both K Means and DBScan. Most of them have a dense cluster with lower values of x and y, and another sparse cluster with higher values of x (3, 6, 8), y (1, 2), or both (9).
# 4. Plots 4, 5, 7, 10, 12, 13 seem almost similar but demonstrate the difference in both the algorithms. The K Means algorithm runs on distance to cluster centres, and so has a perpendicular bisector between them effectively dividing the space into two with a line. DBScan's cluster 1, however, has points which are not seperated by this imaginary bisector, and circle around the denser Cluster 2 in many of the plots.
# 5. Plot 11 has been included to portray how not every dimension when plotted with another can effectively visualize the clusters. The cluster centers are near each other, and DBScan also shows overlapping clusters. This visualization therefore does not provide much information, and needs a different perspective, a newer dimension or an entirely different axis to provide information about the clusters.
# 6. Some interpretations can be made about clusters from these plots, like from plot 3, one can say that there are regions where a lot of milk is bought, but not so much fresh vegetables, and another region where less milk is bought, irrespective of fresh vegetables. It is not clear, however, what the interpretation of most the of plots comes to. It seems that the dataset is not one on which clustering can be successfully employed to gain valuable new information, as it does not return obvious cluster shapes even when plotting all dimensions against each other. There is, however, the issue of columns 1 and 2, channel and region. They were not used in clustering, but when plotted, it is clear that they are already clusters. This makes them labels in the data, and were not used in unsupervised clustering because of exactly the same reason.
